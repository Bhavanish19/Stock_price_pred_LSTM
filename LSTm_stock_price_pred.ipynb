# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# %%
df = pd.read_csv('https://raw.githubusercontent.com/BhavanishDhamnaskar/stk_data/main/Stocks_dataset.csv')
df.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
#No null values in data
df = df[['date','open','close']] #Require columns extracting
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) #Convert to datetime dtype
df.set_index('date', drop=True, inplace=True)
df.head()
# Out:
# <ipython-input-7-5c38fa7f98ef>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) #Convert to datetime dtype
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
# Now we plotting open and closing price on date index
fig, ax = plt.subplots(1,2, figsize=(20,7))
ax[0].plot(df['open'], label = 'open', color = 'green')
ax[0].set_xlabel('Data', size=13)
ax[0].set_ylabel('Price', size=13)
ax[0].legend()

ax[1].plot(df['close'], label = 'Close', color = 'red')
ax[1].set_xlabel('Data', size=13)
ax[1].set_ylabel('Price', size=13)
ax[1].legend()

# %% [markdown]
# # Data preprocessing

# %%
# we'll normalizing all the values of all columns using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
df[df.columns] = mms.fit_transform(df)
df.head()
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732

# %%
#split data into Training and testing
training_size = round(len(df) * 0.75) #75% for training
training_size
# Out:
# 944

# %%
training_data = df[:training_size]
testing_data = df[training_size:]
training_data.shape, testing_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# we'll create sequence of data for training and testing

def create_sequence(dataset):
    sequence = []
    labels = []

    start_idx = 0

    for stop_idx in range(50, len(dataset)): #selecting 50 rows at a time
        sequence.append(dataset.iloc[start_idx:stop_idx])
        labels.append(dataset.iloc[stop_idx])
        start_idx += 1
    return (np.array(sequence), np.array(labels))
train_seq, train_label, = create_sequence(training_data)
test_seq, test_label = create_sequence(testing_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# # LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
#import Sequential from keras.models
model = Sequential()
#import Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs = 100, validation_data = (test_seq, test_label), verbose = 1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 12s 116ms/step - loss: 0.0068 - mean_absolute_error: 0.0574 - val_loss: 0.0175 - val_mean_absolute_error: 0.1102
# Epoch 2/100
# 28/28 [==============================] - 2s 56ms/step - loss: 8.0017e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0046 - val_mean_absolute_error: 0.0532
# Epoch 3/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.5299e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0035 - val_mean_absolute_error: 0.0451
# Epoch 4/100
# 28/28 [==============================] - 2s 56ms/step - loss: 4.4775e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0046 - val_mean_absolute_error: 0.0532
# Epoch 5/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.2340e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0041 - val_mean_absolute_error: 0.0504
# Epoch 6/100
# 28/28 [==============================] - 3s 93ms/step - loss: 4.2912e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0044 - val_mean_absolute_error: 0.0516
# Epoch 7/100
# 28/28 [==============================] - 2s 64ms/step - loss: 4.1017e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0028 - val_mean_absolute_error: 0.0401
# Epoch 8/100
# 28/28 [==============================] - 2s 85ms/step - loss: 4.2773e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0039 - val_mean_absolute_error: 0.0478
# Epoch 9/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.7752e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 10/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.6308e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0043 - val_mean_absolute_error: 0.0508
# Epoch 11/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.8680e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0062 - val_mean_absolute_error: 0.0642
# Epoch 12/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.6720e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0029 - val_mean_absolute_error: 0.0401
# Epoch 13/100
# 28/28 [==============================] - 3s 114ms/step - loss: 3.7949e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0070 - val_mean_absolute_error: 0.0684
# Epoch 14/100
# 28/28 [==============================] - 3s 124ms/step - loss: 3.3649e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0041 - val_mean_absolute_error: 0.0498
# Epoch 15/100
# 28/28 [==============================] - 3s 122ms/step - loss: 3.4163e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0033 - val_mean_absolute_error: 0.0432
# Epoch 16/100
# 28/28 [==============================] - 3s 106ms/step - loss: 3.3796e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0053 - val_mean_absolute_error: 0.0580
# Epoch 17/100
# 28/28 [==============================] - 3s 118ms/step - loss: 3.0308e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0038 - val_mean_absolute_error: 0.0470
# Epoch 18/100
# 28/28 [==============================] - 2s 84ms/step - loss: 2.9910e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0041 - val_mean_absolute_error: 0.0482
# Epoch 19/100
# 28/28 [==============================] - 2s 80ms/step - loss: 3.0799e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0046 - val_mean_absolute_error: 0.0521
# Epoch 20/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.8644e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0052 - val_mean_absolute_error: 0.0566
# Epoch 21/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.8498e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0062 - val_mean_absolute_error: 0.0627
# Epoch 22/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.8845e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0080 - val_mean_absolute_error: 0.0739
# Epoch 23/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.7973e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0051 - val_mean_absolute_error: 0.0555
# Epoch 24/100
# 28/28 [==============================] - 3s 111ms/step - loss: 2.7937e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0053 - val_mean_absolute_error: 0.0561
# Epoch 25/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.5959e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0501
# Epoch 26/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.5655e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0044 - val_mean_absolute_error: 0.0505
# Epoch 27/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.6160e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0062 - val_mean_absolute_error: 0.0612
# Epoch 28/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.4943e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0041 - val_mean_absolute_error: 0.0483
# Epoch 29/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.3314e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0041 - val_mean_absolute_error: 0.0480
# Epoch 30/100
# 28/28 [==============================] - 3s 102ms/step - loss: 2.4471e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0045 - val_mean_absolute_error: 0.0507
# Epoch 31/100
# 28/28 [==============================] - 2s 80ms/step - loss: 2.5774e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0034 - val_mean_absolute_error: 0.0431
# Epoch 32/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.4817e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0050 - val_mean_absolute_error: 0.0565
# Epoch 33/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.3383e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0041 - val_mean_absolute_error: 0.0508
# Epoch 34/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.3020e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0030 - val_mean_absolute_error: 0.0403
# Epoch 35/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.2948e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0039 - val_mean_absolute_error: 0.0496
# Epoch 36/100
# 28/28 [==============================] - 2s 81ms/step - loss: 2.4967e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0046 - val_mean_absolute_error: 0.0543
# Epoch 37/100
# 28/28 [==============================] - 2s 85ms/step - loss: 2.3132e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0033 - val_mean_absolute_error: 0.0430
# Epoch 38/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.2660e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 39/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.1415e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0024 - val_mean_absolute_error: 0.0352
# Epoch 40/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.1231e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0023 - val_mean_absolute_error: 0.0347
# Epoch 41/100
# 28/28 [==============================] - 3s 119ms/step - loss: 2.2304e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0019 - val_mean_absolute_error: 0.0313
# Epoch 42/100
# 28/28 [==============================] - 2s 75ms/step - loss: 2.0985e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0042 - val_mean_absolute_error: 0.0519
# Epoch 43/100
# 28/28 [==============================] - 3s 111ms/step - loss: 2.1435e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0028 - val_mean_absolute_error: 0.0412
# Epoch 44/100
# 28/28 [==============================] - 3s 125ms/step - loss: 1.9525e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0036 - val_mean_absolute_error: 0.0480
# Epoch 45/100
# 28/28 [==============================] - 3s 119ms/step - loss: 2.0303e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0019 - val_mean_absolute_error: 0.0316
# Epoch 46/100
# 28/28 [==============================] - 4s 131ms/step - loss: 2.1866e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0022 - val_mean_absolute_error: 0.0340
# Epoch 47/100
# 28/28 [==============================] - 3s 95ms/step - loss: 2.0714e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0020 - val_mean_absolute_error: 0.0328
# Epoch 48/100
# 28/28 [==============================] - 3s 117ms/step - loss: 2.1938e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0023 - val_mean_absolute_error: 0.0360
# Epoch 49/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8793e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0024 - val_mean_absolute_error: 0.0366
# Epoch 50/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6622e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0020 - val_mean_absolute_error: 0.0327
# Epoch 51/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8219e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 52/100
# 28/28 [==============================] - 3s 115ms/step - loss: 1.8708e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0028 - val_mean_absolute_error: 0.0408
# Epoch 53/100
# 28/28 [==============================] - 2s 86ms/step - loss: 1.9060e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0026 - val_mean_absolute_error: 0.0397
# Epoch 54/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.7394e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0030 - val_mean_absolute_error: 0.0437
# Epoch 55/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8598e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0025 - val_mean_absolute_error: 0.0398
# Epoch 56/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.7137e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0031 - val_mean_absolute_error: 0.0453
# Epoch 57/100
# 28/28 [==============================] - 3s 94ms/step - loss: 1.6396e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0021 - val_mean_absolute_error: 0.0345
# Epoch 58/100
# 28/28 [==============================] - 3s 114ms/step - loss: 1.6796e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0020 - val_mean_absolute_error: 0.0329
# Epoch 59/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.6890e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0023 - val_mean_absolute_error: 0.0364
# Epoch 60/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6457e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0033 - val_mean_absolute_error: 0.0465
# Epoch 61/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6856e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0020 - val_mean_absolute_error: 0.0336
# Epoch 62/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.4862e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0024 - val_mean_absolute_error: 0.0383
# Epoch 63/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.5642e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261
# Epoch 64/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8196e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0021 - val_mean_absolute_error: 0.0356
# Epoch 65/100
# 28/28 [==============================] - 3s 101ms/step - loss: 1.6619e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0017 - val_mean_absolute_error: 0.0314
# Epoch 66/100
# 28/28 [==============================] - 4s 137ms/step - loss: 1.4673e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0015 - val_mean_absolute_error: 0.0281
# Epoch 67/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.5827e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0014 - val_mean_absolute_error: 0.0275
# Epoch 68/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.5258e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 69/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4307e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0012 - val_mean_absolute_error: 0.0250
# Epoch 70/100
# 28/28 [==============================] - 3s 126ms/step - loss: 1.4344e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0018 - val_mean_absolute_error: 0.0321
# Epoch 71/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.4154e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 72/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.4508e-04 - mean_absolute_error: 0.0086 - val_loss: 8.7077e-04 - val_mean_absolute_error: 0.0214
# Epoch 73/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3073e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 74/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3565e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0013 - val_mean_absolute_error: 0.0257
# Epoch 75/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0084 - val_loss: 8.0467e-04 - val_mean_absolute_error: 0.0207
# Epoch 76/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3996e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0014 - val_mean_absolute_error: 0.0274
# Epoch 77/100
# 28/28 [==============================] - 4s 131ms/step - loss: 1.3162e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0016 - val_mean_absolute_error: 0.0299
# Epoch 78/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.2502e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
# Epoch 79/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2608e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324
# Epoch 80/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3639e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0019 - val_mean_absolute_error: 0.0337
# Epoch 81/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1738e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0030 - val_mean_absolute_error: 0.0436
# Epoch 82/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.3184e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0024 - val_mean_absolute_error: 0.0383
# Epoch 83/100
# 28/28 [==============================] - 4s 134ms/step - loss: 1.1715e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
# Epoch 84/100
# 28/28 [==============================] - 4s 143ms/step - loss: 1.2661e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0022 - val_mean_absolute_error: 0.0367
# Epoch 85/100
# 28/28 [==============================] - 4s 148ms/step - loss: 1.2598e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0021 - val_mean_absolute_error: 0.0348
# Epoch 86/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.2097e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0038 - val_mean_absolute_error: 0.0514
# Epoch 87/100
# 28/28 [==============================] - 3s 92ms/step - loss: 1.3731e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0019 - val_mean_absolute_error: 0.0336
# Epoch 88/100
# 28/28 [==============================] - 3s 116ms/step - loss: 1.3077e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 89/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2055e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0014 - val_mean_absolute_error: 0.0273
# Epoch 90/100
# 28/28 [==============================] - 2s 84ms/step - loss: 1.1067e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0016 - val_mean_absolute_error: 0.0302
# Epoch 91/100
# 28/28 [==============================] - 3s 89ms/step - loss: 1.0734e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 92/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1754e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 93/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.3003e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0020 - val_mean_absolute_error: 0.0341
# Epoch 94/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.1876e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 95/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1397e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 96/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1404e-04 - mean_absolute_error: 0.0076 - val_loss: 9.1523e-04 - val_mean_absolute_error: 0.0217
# Epoch 97/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 98/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0798e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 99/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0445e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 100/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.0559e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0018 - val_mean_absolute_error: 0.0323

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 14ms/step
# array([[0.39726293, 0.4031635 ],
#        [0.39733633, 0.4027146 ],
#        [0.39438665, 0.39933276],
#        [0.39761066, 0.4032418 ],
#        [0.40111274, 0.40719104]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = mms.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1407.4937, 1415.4591],
#        [1407.6298, 1414.6272],
#        [1402.1613, 1408.3594],
#        [1408.1384, 1415.6042],
#        [1414.631 , 1422.9235]], dtype=float32)

# %% [markdown]
# # Predicted data and Visualising actual data

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = mms.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1407.493652      1415.459106
# 2020-05-28  1396.86  1416.73     1407.629761      1414.627197
# 2020-05-29  1416.94  1428.92     1402.161255      1408.359375
# 2020-06-01  1418.39  1431.82     1408.138428      1415.604248
# 2020-06-02  1430.55  1439.22     1414.630981      1422.923462

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
# <ipython-input-22-106f0ea24868>:4: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
# <ipython-input-22-106f0ea24868>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2306.636963      2352.832031
# 2021-06-10  2494.01  2521.60     2309.531006      2352.653809
# 2021-06-11  2524.92  2513.93     2321.623535      2364.929443
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = mms.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
